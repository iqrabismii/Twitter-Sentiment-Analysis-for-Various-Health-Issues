# %% [markdown]
# ### 1. Data Extraction

# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
import time
import statistics
import numpy as np
import matplotlib.pyplot as plt
import random
import seaborn as sns
import math
import nltk
import string
import re
from nltk.util import ngrams
import sklearn
import emoji

# %%
# Use of Bearer Token

os.environ['TOKEN'] = 'AAAAAAAAAAAAAAAAAAAAAOY3eQEAAAAA%2FK0FPI1vVnopel6JTVkr3Xub%2BlE%3Dpbokl1iPkF9foae0YEnAfsmUBt2jsF0DMss8nvElve8Z8dhoVL'
# os.environ['TOKEN'] = 'AAAAAAAAAAAAAAAAAAAAAIu3dQEAAAAAv%2Bz8dWQYjA0ZOWHJlcu%2FFIUiFjA%3Dn54h9wPaU6iRsCwWKAlanfprENYSf98Rbups3bltouPpdDULUf'

# %%
# Auth function to retrieve the bearer token from the environment

def auth():
    return os.getenv('TOKEN')

# %%
# Creating headers

def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
# Creating URLs

def create_url(keyword, start_date, end_date, max_results = 10):
    
    search_url = "https://api.twitter.com/2/tweets/search/all" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

# %%
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
def append_to_csv_updated(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for tweet in json_response['data']:
        
        # We will create a variable for each since some of the keys might not exist for some tweets
        # So we will account for that

        # 1. Author ID
        author_id = tweet['author_id']

        # 2. Time created
        created_at = dateutil.parser.parse(tweet['created_at'])

        # 3. Geolocation
        if ('geo' in tweet):   
            geo = tweet['geo']['place_id']
        else:
            geo = " "

        # 4. Tweet ID
        tweet_id = tweet['id']

        # 5. Language
        lang = tweet['lang']

        # 6. Tweet metrics
        retweet_count = tweet['public_metrics']['retweet_count']
        reply_count = tweet['public_metrics']['reply_count']
        like_count = tweet['public_metrics']['like_count']
        quote_count = tweet['public_metrics']['quote_count']

        # 7. source
        source = tweet['source']

        # 8. Tweet text
        text = tweet['text']
        
        # 9. Possibly sensitive
        reply_settings = tweet['reply_settings']
        
        # 10. Conversation id 
        conversation_id = tweet['conversation_id']
        
        # 11. Referenced tweets type
        if ('referenced_tweets' in tweet):
            referenced_tweets_type = tweet['referenced_tweets']
        else:
            referenced_tweets_type = ""
        
        # 12. Referenced tweets id
        if ('referenced_tweets' in tweet):
            referenced_tweets_id = tweet['referenced_tweets']
        else:
            referenced_tweets_id = ""
        
        # 13. Reply to
        if ('in_reply_to_user_id' in tweet):
            in_reply_to_user_id = tweet['in_reply_to_user_id']
        else:
            in_reply_to_user_id = ""
        
        
        # Assemble all data in a list
        res = [author_id, created_at, geo, tweet_id, lang, like_count, quote_count, reply_count, retweet_count,\
               source, text, reply_settings, conversation_id, referenced_tweets_type, referenced_tweets_id, \
               in_reply_to_user_id]
        
       
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Tweets added from this response: ", counter)

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta
now = datetime.now()
current_datetime = now.strftime("%d%m_%H%M%S")
filename = 'data' + current_datetime + '.csv'
filename
# Out:
# 'data0308_142922.csv'

# %%
# Modifying the query based on the parameters
#Inputs for tweets
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "congestive heart failure lang:en"

start_list = []
end_list = []

date = datetime(2017, 1, 1)
start_date = date


for i in range(53):
    start_date_formatted = start_date.isoformat() + '.000Z'
    start_list.append(start_date_formatted)

    end_date = start_date + relativedelta(months=1) - relativedelta(days=1)
    end_date_formatted = end_date.isoformat() + '.000Z'
    end_list.append(end_date_formatted)

    start_date += relativedelta(months=1)


max_results = 500

#Total number of tweets we collected from the loop
total_tweets = 0

# Create file
csvFile = open(filename, "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
csvWriter.writerow(['author id', 'created_at', 'geo', 'id','lang', 'like_count', 'quote_count', \
                    'reply_count','retweet_count','source','tweet','reply_settings', 'conversation_id', \
                    'referenced_tweets_type', 'referenced_tweets_id', 'in_reply_to_user_id'])
csvFile.close()

for i in range(0,len(start_list)):

    # Inputs
    count = 0 # Counting tweets per time period
    max_count = 100 # Max tweets per time period
    flag = True
    next_token = None
    
    # Check if flag is true
    while flag:
        # Check if max_count reached
        if count >= max_count:
            break
        print("-------------------")
        print("Token: ", next_token)
        url = create_url(keyword, start_list[i],end_list[i], max_results)
        json_response = connect_to_endpoint(url[0], headers, url[1], next_token)
        result_count = json_response['meta']['result_count']

        if 'next_token' in json_response['meta']:
            # Save the token to use for next call
            next_token = json_response['meta']['next_token']
            print("Next Token: ", next_token)
            if result_count is not None and result_count > 0 and next_token is not None:
                print("Start Date: ", start_list[i])
                append_to_csv_updated(json_response, filename)
                count += result_count
                total_tweets += result_count
                print("Total # of Tweets added: ", total_tweets)
                print("-------------------")
                time.sleep(5)                
        # If no next token exists
        else:
            if result_count is not None and result_count > 0:
                print("-------------------")
                print("Start Date: ", start_list[i])
                append_to_csv_updated(json_response, filename)
                count += result_count
                total_tweets += result_count
                print("Total # of Tweets added: ", total_tweets)
                print("-------------------")
                time.sleep(5)
            
            #Since this is the final request, turn flag to false to move to the next time period.
            flag = False
            next_token = None
        time.sleep(5)
print("Total number of results: ", total_tweets)
# Out:
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw3j143m755qizqntgnmfcbkmg8kg3h
# Start Date:  2017-01-01T00:00:00.000Z
# # of Tweets added from this response:  487
# Total # of Tweets added:  487
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw3j70absru042zcvi0ge6hgejxelbx
# Start Date:  2017-02-01T00:00:00.000Z
# # of Tweets added from this response:  491
# Total # of Tweets added:  978
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw3ja0wrjv5yzrxgtqknq6844v7rn25
# Start Date:  2017-03-01T00:00:00.000Z
# # of Tweets added from this response:  491
# Total # of Tweets added:  1469
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw3jd0957cmbcnqtb5arjfiwt97ec8t
# Start Date:  2017-04-01T00:00:00.000Z
# # of Tweets added from this response:  496
# Total # of Tweets added:  1965
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw3jg017nbsgcg5a24066bsfkfgn81p
# Start Date:  2017-05-01T00:00:00.000Z
# # of Tweets added from this response:  481
# Total # of Tweets added:  2446
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw3jj0875fsgfkb2fd2ots5ypp94w3h
# Start Date:  2017-06-01T00:00:00.000Z
# # of Tweets added from this response:  493
# Total # of Tweets added:  2939
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw3jm1opnwq48h9emrkj3wlqxsd24jh
# Start Date:  2017-07-01T00:00:00.000Z
# # of Tweets added from this response:  492
# Total # of Tweets added:  3431
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw3jp1vvie6fd12torb44n4bi6azed9
# Start Date:  2017-08-01T00:00:00.000Z
# # of Tweets added from this response:  498
# Total # of Tweets added:  3929
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw448inmzeoukkwy7u2c9d2uxfpoc59
# Start Date:  2017-09-01T00:00:00.000Z
# # of Tweets added from this response:  460
# Total # of Tweets added:  4389
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw44bifpcdvmfktkpez73dpwtylem4d
# Start Date:  2017-10-01T00:00:00.000Z
# # of Tweets added from this response:  483
# Total # of Tweets added:  4872
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw44hem8l1nb5snuwf2z1oov8vn6i65
# Start Date:  2017-11-01T00:00:00.000Z
# # of Tweets added from this response:  487
# Total # of Tweets added:  5359
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw44keszlfyl5uzsrg1j55thkjt3799
# Start Date:  2017-12-01T00:00:00.000Z
# # of Tweets added from this response:  489
# Total # of Tweets added:  5848
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw44nfffdfqtx4g24wiobxb1xy0flod
# Start Date:  2018-01-01T00:00:00.000Z
# # of Tweets added from this response:  485
# Total # of Tweets added:  6333
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw44qg19symz4346yc5raqzih9fenb1
# Start Date:  2018-02-01T00:00:00.000Z
# # of Tweets added from this response:  490
# Total # of Tweets added:  6823
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw44tfeax1ih1hddmgk7c2j0ogu27wd
# Start Date:  2018-03-01T00:00:00.000Z
# # of Tweets added from this response:  486
# Total # of Tweets added:  7309
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw44wflixrbbvzx35q0rtmloamgafst
# Start Date:  2018-04-01T00:00:00.000Z
# # of Tweets added from this response:  495
# Total # of Tweets added:  7804
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  1jzu9lk96gu5npw44zgmgvp0d6g41mk8wwuxbk8d422l
# Start Date:  2018-05-01T00:00:00.000Z
# # of Tweets added from this response:  473
# Total # of Tweets added:  8277
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fn0apeleq13s3s5fmpjhwrrvzn3ou5
# Start Date:  2018-06-01T00:00:00.000Z
# # of Tweets added from this response:  490
# Total # of Tweets added:  8767
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fn0glkpo79xn4hqg6nrf4zh0xnod4t
# Start Date:  2018-07-01T00:00:00.000Z
# # of Tweets added from this response:  479
# Total # of Tweets added:  9246
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fn0jlrp7i82byim5vgp413at1ite9p
# Start Date:  2018-08-01T00:00:00.000Z
# # of Tweets added from this response:  486
# Total # of Tweets added:  9732
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fn0mme73bht4cov0iqlelal6bw4rjx
# Start Date:  2018-09-01T00:00:00.000Z
# # of Tweets added from this response:  492
# Total # of Tweets added:  10224
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fn0plqmvjn7ythvw1j5it619lje1z1
# Start Date:  2018-10-01T00:00:00.000Z
# # of Tweets added from this response:  488
# Total # of Tweets added:  10712
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fn0sn7dv49laso1vl0vz6etbu3o3ul
# Start Date:  2018-11-01T00:00:00.000Z
# # of Tweets added from this response:  492
# Total # of Tweets added:  11204
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fn0vm4uggw2zu5263wr0j2db2zntkt
# Start Date:  2018-12-01T00:00:00.000Z
# # of Tweets added from this response:  447
# Total # of Tweets added:  11651
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fn0ynlnl2d5cm0bgnqt9jx2ed37vjx
# Start Date:  2019-01-01T00:00:00.000Z
# # of Tweets added from this response:  497
# Total # of Tweets added:  12148
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fn11mxwx0c0n15ov53sdtx9wnxlqil
# Start Date:  2019-02-01T00:00:00.000Z
# # of Tweets added from this response:  478
# Total # of Tweets added:  12626
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fnlnzpeeumfftnu4uwr1y6c71sbz3x
# Start Date:  2019-03-01T00:00:00.000Z
# # of Tweets added from this response:  481
# Total # of Tweets added:  13107
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fnlo3301jj49y6kjlctsheu8jhir25
# Start Date:  2019-04-01T00:00:00.000Z
# # of Tweets added from this response:  487
# Total # of Tweets added:  13594
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fnltzogdj8vlv21x0m1m5eob34mm4d
# Start Date:  2019-05-01T00:00:00.000Z
# # of Tweets added from this response:  477
# Total # of Tweets added:  14071
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fnlwzvdpf0ucovordjhkc4wpx69h19
# Start Date:  2019-06-01T00:00:00.000Z
# # of Tweets added from this response:  489
# Total # of Tweets added:  14560
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fnm002q0hvcckayk4qk5m42nz7g3gd
# Start Date:  2019-07-01T00:00:00.000Z
# # of Tweets added from this response:  464
# Total # of Tweets added:  15024
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fnm309l9g3zqav4s8yjizxg9izmlx9
# Start Date:  2019-08-01T00:00:00.000Z
# # of Tweets added from this response:  476
# Total # of Tweets added:  15500
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fnm60ggj0foweenuu4x7tmao3ekcjh
# Start Date:  2019-09-01T00:00:00.000Z
# # of Tweets added from this response:  486
# Total # of Tweets added:  15986
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fnm908iyz9owtydgmq24l06rhiw1vh
# Start Date:  2019-10-01T00:00:00.000Z
# # of Tweets added from this response:  482
# Total # of Tweets added:  16468
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fnmc19pebzin2wcjmckoge2zftotj1
# Start Date:  2019-11-01T00:00:00.000Z
# # of Tweets added from this response:  477
# Total # of Tweets added:  16945
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6vhn0swv0oddysyv6rqwgkjtg77h
# Start Date:  2019-12-01T00:00:00.000Z
# # of Tweets added from this response:  488
# Total # of Tweets added:  17433
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo6yhu0ctw7sxvwtzu1bb7yaqcp3zx
# Start Date:  2020-01-01T00:00:00.000Z
# # of Tweets added from this response:  485
# Total # of Tweets added:  17918
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo74dl7hghk17n9ncanw11gagu93el
# Start Date:  2020-02-01T00:00:00.000Z
# # of Tweets added from this response:  469
# Total # of Tweets added:  18387
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77embtvvoku26moikq9eeaakz8fx
# Start Date:  2020-03-01T00:00:00.000Z
# # of Tweets added from this response:  466
# Total # of Tweets added:  18853
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7aeec5q9pbodx1jecg72mkufqef1
# Start Date:  2020-04-01T00:00:00.000Z
# # of Tweets added from this response:  421
# Total # of Tweets added:  19274
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7delbo4z3ywyvs37gqwta5vfo0vx
# Start Date:  2020-05-01T00:00:00.000Z
# # of Tweets added from this response:  450
# Total # of Tweets added:  19724
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7gf7n79x1thv69h6ajl8mxxskwvx
# Start Date:  2020-06-01T00:00:00.000Z
# # of Tweets added from this response:  408
# Total # of Tweets added:  20132
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7jfeos0kvss1kgt6rbma0ucf34ot
# Start Date:  2020-07-01T00:00:00.000Z
# # of Tweets added from this response:  460
# Total # of Tweets added:  20592
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7mflhxfvfz8hrnaru6062ibtpojh
# Start Date:  2020-08-01T00:00:00.000Z
# # of Tweets added from this response:  474
# Total # of Tweets added:  21066
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5wdwscnkrljve1fe2jzzp9ziem5
# Start Date:  2020-09-01T00:00:00.000Z
# # of Tweets added from this response:  473
# Total # of Tweets added:  21539
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosbs53zoow545a1hvhivxpx7pgfb1
# Start Date:  2020-10-01T00:00:00.000Z
# # of Tweets added from this response:  445
# Total # of Tweets added:  21984
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foserwzzdodqmh7wq972haxvv8phfh
# Start Date:  2020-11-01T00:00:00.000Z
# # of Tweets added from this response:  454
# Total # of Tweets added:  22438
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshsjbiia78tz8csl1el127phzxj1
# Start Date:  2020-12-01T00:00:00.000Z
# # of Tweets added from this response:  470
# Total # of Tweets added:  22908
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosktkdqsw8tezv0hhn3wqtcdlm0e5
# Start Date:  2021-01-01T00:00:00.000Z
# # of Tweets added from this response:  58
# Total # of Tweets added:  22966
# -------------------
# -------------------
# Token:  b26v89c19zqg8o3fosktkdqsw8tezv0hhn3wqtcdlm0e5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foskt5849fu9i1aiotpzv29yn81im5
# Start Date:  2021-01-01T00:00:00.000Z
# # of Tweets added from this response:  147
# Total # of Tweets added:  23113
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnsidhhzmswlflunkpuzlml22mbh
# Start Date:  2021-02-01T00:00:00.000Z
# # of Tweets added from this response:  431
# Total # of Tweets added:  23544
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosqsp6lqglee91m03l9la7lzk4ebh
# Start Date:  2021-03-01T00:00:00.000Z
# # of Tweets added from this response:  471
# Total # of Tweets added:  24015
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fostsh91pl69xzeibifrvjzhiq94e5
# Start Date:  2021-04-01T00:00:00.000Z
# # of Tweets added from this response:  464
# Total # of Tweets added:  24479
# -------------------
# -------------------
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foswt3e55o9vknj4391dymix8gvji5
# Start Date:  2021-05-01T00:00:00.000Z
# # of Tweets added from this response:  379
# Total # of Tweets added:  24858
# -------------------
# Total number of results:  24858

# %% [markdown]
# ### 2. Data Wrangling
# ### <ensp> 2.a. Cleaning
# #### 2.a.i Handling duplicate tweets:

# %%
# filename = 'data0108_164439.csv'
df_ed = pd.read_csv(filename)

# %%
df_ed.head()
# Out:
#             author id                 created_at geo                  id lang  \
# 0           841096634  2017-01-30 23:58:56+00:00      826218167173144577   en
# 1  748946534394368002  2017-01-30 23:50:21+00:00      826216010097233920   en
# 2           135120971  2017-01-30 23:30:19+00:00      826210969152000000   en
# 3          3306037131  2017-01-30 19:02:15+00:00      826143504829186048   en
# 4           570962879  2017-01-30 18:57:09+00:00      826142220646486017   en
#
#    like_count  quote_count  reply_count  retweet_count               source  \
# 0          17            0            2              0   Twitter for iPhone
# 1           0            0            0              0   Twitter Web Client
# 2           0            0            0              0            Hootsuite
# 3           0            0            0              0       Tweet Old Post
# 4           9            0            0              0  Twitter for Android
#
#                                                tweet reply_settings  \
# 0  A year ago today my mom got diagnosed w/ conge...       everyone
# 1  @PodcastSchmucks @JonTronShow George Michael's...       everyone
# 2  ICYMI, #HeartAttack, #AtrialFibrillation, cong...       everyone
# 3  Q&amp;A 245 - Birthday Wishes, Lost Memories, ...       everyone
# 4  🔘Cardiac Cirrhosis《congestive Hepatopathy》:   ...       everyone
#
#       conversation_id                             referenced_tweets_type  \
# 0  826218167173144577                                                NaN
# 1  826197950531457024  [{'type': 'replied_to', 'id': '826197950531457...
# 2  826210969152000000                                                NaN
# 3  826143504829186048                                                NaN
# 4  826142220646486017                                                NaN
#
#                                 referenced_tweets_id  in_reply_to_user_id
# 0                                                NaN                  NaN
# 1  [{'type': 'replied_to', 'id': '826197950531457...         7.754213e+17
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN

# %%
df = df_ed[df_ed.referenced_tweets_type.isna()]

# %%
print(f'Count of tweets for ED: {len(df_ed)}')
# Out:
# Count of tweets for ED: 24858

# %%
df.head()
# Out:
#     author id                 created_at geo                  id lang  \
# 0   841096634  2017-01-30 23:58:56+00:00      826218167173144577   en
# 2   135120971  2017-01-30 23:30:19+00:00      826210969152000000   en
# 3  3306037131  2017-01-30 19:02:15+00:00      826143504829186048   en
# 4   570962879  2017-01-30 18:57:09+00:00      826142220646486017   en
# 6    46431668  2017-01-30 18:01:43+00:00      826128271263801344   en
#
#    like_count  quote_count  reply_count  retweet_count               source  \
# 0          17            0            2              0   Twitter for iPhone
# 2           0            0            0              0            Hootsuite
# 3           0            0            0              0       Tweet Old Post
# 4           9            0            0              0  Twitter for Android
# 6           0            0            0              0   Twitter Web Client
#
#                                                tweet reply_settings  \
# 0  A year ago today my mom got diagnosed w/ conge...       everyone
# 2  ICYMI, #HeartAttack, #AtrialFibrillation, cong...       everyone
# 3  Q&amp;A 245 - Birthday Wishes, Lost Memories, ...       everyone
# 4  🔘Cardiac Cirrhosis《congestive Hepatopathy》:   ...       everyone
# 6  Thanks to all who attended our Lunch &amp; Lea...       everyone
#
#       conversation_id referenced_tweets_type referenced_tweets_id  \
# 0  826218167173144577                    NaN                  NaN
# 2  826210969152000000                    NaN                  NaN
# 3  826143504829186048                    NaN                  NaN
# 4  826142220646486017                    NaN                  NaN
# 6  826128271263801344                    NaN                  NaN
#
#    in_reply_to_user_id
# 0                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 6                  NaN

# %%
print(f'Count of tweets for ED after removing the duplicates: {len(df)}')
# Out:
# Count of tweets for ED after removing the duplicates: 7944

# %% [markdown]
# #### 2.a.iv Removal of \n, \t, \&gt;

# %%
df['tweet'] = df['tweet'].apply(lambda x: x.replace('&gt;|\n|\t', ''))
# Out:
# C:\Users\REVATH~1\AppData\Local\Temp/ipykernel_16876/2617722484.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tweet'] = df['tweet'].apply(lambda x: x.replace('&gt;|\n|\t', ''))

# %% [markdown]
# #### 2.a.ii Hyperlinks:

# %%
def presence(x,text):
    if text in x:
        return 1
    else:
        return 0

# %%
df['hyperlink_tag']=df['tweet'].apply(lambda x: presence(x,'http'))
# Out:
# C:\Users\REVATH~1\AppData\Local\Temp/ipykernel_16876/192578393.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hyperlink_tag']=df['tweet'].apply(lambda x: presence(x,'http'))

# %%
df['hyperlink_tag'].value_counts()
# Out:
# 1    5510
# 0    2434
# Name: hyperlink_tag, dtype: int64

# %%
df['Tweet_exc_link']=df['tweet'].apply(lambda x: re.sub(r"http\S+|www.\S+|Https.\S+", "",x))
df['Tweet_inc_link']=df['tweet'].apply(lambda x: re.findall("(http\S+|www.\S+|Https.\S+)",x))
df['Tweet_inc_link']=df['Tweet_inc_link'].apply(lambda x: str(x).replace("[","").replace("]","").strip())
# Out:
# C:\Users\REVATH~1\AppData\Local\Temp/ipykernel_16876/3729918035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tweet_exc_link']=df['tweet'].apply(lambda x: re.sub(r"http\S+|www.\S+|Https.\S+", "",x))
# C:\Users\REVATH~1\AppData\Local\Temp/ipykernel_16876/3729918035.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tweet_inc_link']=df['tweet'].apply(lambda x: re.findall("(http\S+|www.\S+|Https.\S+)",x))
# C:\Users\REVATH~1\AppData\Local\Temp/ipykernel_16876/3729918035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tweet_inc_link']=df['Tweet_inc_link'].apply(lambda x: str(x).replace("[","").replace("]","").strip())

# %%
df.head()
# Out:
#     author id                 created_at geo                  id lang  \
# 0   841096634  2017-01-30 23:58:56+00:00      826218167173144577   en
# 2   135120971  2017-01-30 23:30:19+00:00      826210969152000000   en
# 3  3306037131  2017-01-30 19:02:15+00:00      826143504829186048   en
# 4   570962879  2017-01-30 18:57:09+00:00      826142220646486017   en
# 6    46431668  2017-01-30 18:01:43+00:00      826128271263801344   en
#
#    like_count  quote_count  reply_count  retweet_count               source  \
# 0          17            0            2              0   Twitter for iPhone
# 2           0            0            0              0            Hootsuite
# 3           0            0            0              0       Tweet Old Post
# 4           9            0            0              0  Twitter for Android
# 6           0            0            0              0   Twitter Web Client
#
#                                                tweet reply_settings  \
# 0  A year ago today my mom got diagnosed w/ conge...       everyone
# 2  ICYMI, #HeartAttack, #AtrialFibrillation, cong...       everyone
# 3  Q&amp;A 245 - Birthday Wishes, Lost Memories, ...       everyone
# 4  🔘Cardiac Cirrhosis《congestive Hepatopathy》:   ...       everyone
# 6  Thanks to all who attended our Lunch &amp; Lea...       everyone
#
#       conversation_id referenced_tweets_type referenced_tweets_id  \
# 0  826218167173144577                    NaN                  NaN
# 2  826210969152000000                    NaN                  NaN
# 3  826143504829186048                    NaN                  NaN
# 4  826142220646486017                    NaN                  NaN
# 6  826128271263801344                    NaN                  NaN
#
#    in_reply_to_user_id  hyperlink_tag  \
# 0                  NaN              0
# 2                  NaN              1
# 3                  NaN              1
# 4                  NaN              0
# 6                  NaN              1
#
#                                       Tweet_exc_link  \
# 0  A year ago today my mom got diagnosed w/ conge...
# 2  ICYMI, #HeartAttack, #AtrialFibrillation, cong...
# 3  Q&amp;A 245 - Birthday Wishes, Lost Memories, ...
# 4  🔘Cardiac Cirrhosis《congestive Hepatopathy》:   ...
# 6  Thanks to all who attended our Lunch &amp; Lea...
#
#                                       Tweet_inc_link
# 0
# 2  'https://t.co/Qwlpx3MAo5', 'https://t.co/U3XKz...
# 3                          'https://t.co/g0PmHFxrxX'
# 4
# 6  'https://t.co/BO9q3L0Gvb', 'https://t.co/OaSVb...

# %% [markdown]
# #### 2.a.iii Hashtag removal:

# %%
df['Tweet_exc_hash']=df['Tweet_exc_link'].apply(lambda x: x.replace('#','').strip())
df['Tweet_hashtag_inc']=df['Tweet_exc_link'].apply(lambda x: re.findall("#(\S+)",x))
df['Tweet_hashtag_inc']=df['Tweet_hashtag_inc'].apply(lambda x: " ".join(x))
# Out:
# C:\Users\REVATH~1\AppData\Local\Temp/ipykernel_16876/1925447993.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tweet_exc_hash']=df['Tweet_exc_link'].apply(lambda x: x.replace('#','').strip())
# C:\Users\REVATH~1\AppData\Local\Temp/ipykernel_16876/1925447993.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tweet_hashtag_inc']=df['Tweet_exc_link'].apply(lambda x: re.findall("#(\S+)",x))
# C:\Users\REVATH~1\AppData\Local\Temp/ipykernel_16876/1925447993.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tweet_hashtag_inc']=df['Tweet_hashtag_inc'].apply(lambda x: " ".join(x))

# %%
# pip install emoji

# %%
df['tweet_formatted'] = df['Tweet_exc_hash'].apply(lambda x: emoji.demojize(x))
# Out:
# C:\Users\REVATH~1\AppData\Local\Temp/ipykernel_16876/1686721244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tweet_formatted'] = df['Tweet_exc_hash'].apply(lambda x: emoji.demojize(x))

# %%
df.head()
# Out:
#     author id                 created_at geo                  id lang  \
# 0   841096634  2017-01-30 23:58:56+00:00      826218167173144577   en
# 2   135120971  2017-01-30 23:30:19+00:00      826210969152000000   en
# 3  3306037131  2017-01-30 19:02:15+00:00      826143504829186048   en
# 4   570962879  2017-01-30 18:57:09+00:00      826142220646486017   en
# 6    46431668  2017-01-30 18:01:43+00:00      826128271263801344   en
#
#    like_count  quote_count  reply_count  retweet_count               source  \
# 0          17            0            2              0   Twitter for iPhone
# 2           0            0            0              0            Hootsuite
# 3           0            0            0              0       Tweet Old Post
# 4           9            0            0              0  Twitter for Android
# 6           0            0            0              0   Twitter Web Client
#
#    ...     conversation_id referenced_tweets_type  referenced_tweets_id  \
# 0  ...  826218167173144577                    NaN                   NaN
# 2  ...  826210969152000000                    NaN                   NaN
# 3  ...  826143504829186048                    NaN                   NaN
# 4  ...  826142220646486017                    NaN                   NaN
# 6  ...  826128271263801344                    NaN                   NaN
#
#   in_reply_to_user_id hyperlink_tag  \
# 0                 NaN             0
# 2                 NaN             1
# 3                 NaN             1
# 4                 NaN             0
# 6                 NaN             1
#
#                                       Tweet_exc_link  \
# 0  A year ago today my mom got diagnosed w/ conge...
# 2  ICYMI, #HeartAttack, #AtrialFibrillation, cong...
# 3  Q&amp;A 245 - Birthday Wishes, Lost Memories, ...
# 4  🔘Cardiac Cirrhosis《congestive Hepatopathy》:   ...
# 6  Thanks to all who attended our Lunch &amp; Lea...
#
#                                       Tweet_inc_link  \
# 0
# 2  'https://t.co/Qwlpx3MAo5', 'https://t.co/U3XKz...
# 3                          'https://t.co/g0PmHFxrxX'
# 4
# 6  'https://t.co/BO9q3L0Gvb', 'https://t.co/OaSVb...
#
#                                       Tweet_exc_hash  \
# 0  A year ago today my mom got diagnosed w/ conge...
# 2  ICYMI, HeartAttack, AtrialFibrillation, conges...
# 3  Q&amp;A 245 - Birthday Wishes, Lost Memories, ...
# 4  🔘Cardiac Cirrhosis《congestive Hepatopathy》:   ...
# 6  Thanks to all who attended our Lunch &amp; Lea...
#
#                                    Tweet_hashtag_inc  \
# 0
# 2  HeartAttack, AtrialFibrillation, HeartFailure ...
# 3
# 4
# 6
#
#                                      tweet_formatted
# 0  A year ago today my mom got diagnosed w/ conge...
# 2  ICYMI, HeartAttack, AtrialFibrillation, conges...
# 3  Q&amp;A 245 - Birthday Wishes, Lost Memories, ...
# 4  :radio_button:Cardiac Cirrhosis《congestive Hep...
# 6  Thanks to all who attended our Lunch &amp; Lea...
#
# [5 rows x 22 columns]

# %%
contractions = {
"ain't": "am not / are not",
"aren't": "are not / am not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he had / he would",
"he'd've": "he would have",
"he'll": "he shall / he will",
"he'll've": "he shall have / he will have",
"he's": "he has / he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how has / how is",
"i'd": "I had / I would",
"i'd've": "I would have",
"i'll": "I shall / I will",
"i'll've": "I shall have / I will have",
"i'm": "I am",
"i've": "I have",
"isn't": "is not",
"it'd": "it had / it would",
"it'd've": "it would have",
"it'll": "it shall / it will",
"it'll've": "it shall have / it will have",
"it's": "it has / it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she had / she would",
"she'd've": "she would have",
"she'll": "she shall / she will",
"she'll've": "she shall have / she will have",
"she's": "she has / she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as / so is",
"that'd": "that would / that had",
"that'd've": "that would have",
"that's": "that has / that is",
"there'd": "there had / there would",
"there'd've": "there would have",
"there's": "there has / there is",
"they'd": "they had / they would",
"they'd've": "they would have",
"they'll": "they shall / they will",
"they'll've": "they shall have / they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we had / we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what shall / what will",
"what'll've": "what shall have / what will have",
"what're": "what are",
"what's": "what has / what is",
"what've": "what have",
"when's": "when has / when is",
"when've": "when have",
"where'd": "where did",
"where's": "where has / where is",
"where've": "where have",
"who'll": "who shall / who will",
"who'll've": "who shall have / who will have",
"who's": "who has / who is",
"who've": "who have",
"why's": "why has / why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you had / you would",
"you'd've": "you would have",
"you'll": "you shall / you will",
"you'll've": "you shall have / you will have",
"you're": "you are",
"you've": "you have"
}

# %%
# Steps for text cleaning 

df = df.astype(str)

from spellchecker import SpellChecker

def text_cleaning(x):
    norm_text = x[0].upper() + x[1:] # Step I. Normalizing text
    for word in norm_text.split(): # Step II. Handling the contraction text
        if word.lower() in contractions:
            norm_text = norm_text.replace(word, contractions[word.lower()])
    rem_unicode = re.sub(r"[^a-zA-Z0-9 /,?]+", "", norm_text) #Step III. Removing Unicode Characters
#     rem_unicode = re.sub(r"(@\[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", norm_text) # Step III. Removing unicode characters
    return rem_unicode

# spell = SpellChecker()

df['tweet_formatted'] = df['tweet_formatted'].apply(text_cleaning)
# df['tweet_formatted'] = df['tweet_formatted'].apply(lambda x: spell.correction(x))

# %%
df.head()
# Out:
#     author id                 created_at geo                  id lang  \
# 0   841096634  2017-01-30 23:58:56+00:00      826218167173144577   en
# 2   135120971  2017-01-30 23:30:19+00:00      826210969152000000   en
# 3  3306037131  2017-01-30 19:02:15+00:00      826143504829186048   en
# 4   570962879  2017-01-30 18:57:09+00:00      826142220646486017   en
# 6    46431668  2017-01-30 18:01:43+00:00      826128271263801344   en
#
#   like_count quote_count reply_count retweet_count               source  ...  \
# 0         17           0           2             0   Twitter for iPhone  ...
# 2          0           0           0             0            Hootsuite  ...
# 3          0           0           0             0       Tweet Old Post  ...
# 4          9           0           0             0  Twitter for Android  ...
# 6          0           0           0             0   Twitter Web Client  ...
#
#       conversation_id referenced_tweets_type referenced_tweets_id  \
# 0  826218167173144577                    nan                  nan
# 2  826210969152000000                    nan                  nan
# 3  826143504829186048                    nan                  nan
# 4  826142220646486017                    nan                  nan
# 6  826128271263801344                    nan                  nan
#
#   in_reply_to_user_id hyperlink_tag  \
# 0                 nan             0
# 2                 nan             1
# 3                 nan             1
# 4                 nan             0
# 6                 nan             1
#
#                                       Tweet_exc_link  \
# 0  A year ago today my mom got diagnosed w/ conge...
# 2  ICYMI, #HeartAttack, #AtrialFibrillation, cong...
# 3  Q&amp;A 245 - Birthday Wishes, Lost Memories, ...
# 4  🔘Cardiac Cirrhosis《congestive Hepatopathy》:   ...
# 6  Thanks to all who attended our Lunch &amp; Lea...
#
#                                       Tweet_inc_link  \
# 0
# 2  'https://t.co/Qwlpx3MAo5', 'https://t.co/U3XKz...
# 3                          'https://t.co/g0PmHFxrxX'
# 4
# 6  'https://t.co/BO9q3L0Gvb', 'https://t.co/OaSVb...
#
#                                       Tweet_exc_hash  \
# 0  A year ago today my mom got diagnosed w/ conge...
# 2  ICYMI, HeartAttack, AtrialFibrillation, conges...
# 3  Q&amp;A 245 - Birthday Wishes, Lost Memories, ...
# 4  🔘Cardiac Cirrhosis《congestive Hepatopathy》:   ...
# 6  Thanks to all who attended our Lunch &amp; Lea...
#
#                                    Tweet_hashtag_inc  \
# 0
# 2  HeartAttack, AtrialFibrillation, HeartFailure ...
# 3
# 4
# 6
#
#                                      tweet_formatted
# 0  A year ago today my mom got diagnosed w/ conge...
# 2  ICYMI, HeartAttack, AtrialFibrillation, conges...
# 3  QampA 245  Birthday Wishes, Lost Memories, Con...
# 4  radiobuttonCardiac Cirrhosiscongestive Hepatop...
# 6  Thanks to all who attended our Lunch amp Learn...
#
# [5 rows x 22 columns]

# %%
df['tweet_formatted_lower'] = df['tweet_formatted'].str.lower()

# %%
df['interrogative']=df['tweet'].apply(lambda x:1 if '?' in x else 0)

# %%
df['interrogative'].value_counts()
# Out:
# 0    7265
# 1     679
# Name: interrogative, dtype: int64

# %%
# Checking the distribution of the links mentioned
from collections import  Counter
from nltk.corpus import stopwords

def plot_top_non_stopwords_barchart(text):
    stop=set(stopwords.words('english'))
    
    new= text.str.split()
    new=new.values.tolist()
    corpus=[word for i in new for word in i]

    counter=Counter(corpus)
    most=counter.most_common()
    x, y=[], []
    for word,count in most[:20]:
        if (word not in stop):
            x.append(word)
            y.append(count)
    plt.figure(figsize=(15,8))
    sns.barplot(x=y,y=x)

plot_top_non_stopwords_barchart(df['Tweet_inc_link'])

# Explore more such analysis here - https://neptune.ai/blog/exploratory-data-analysis-natural-language-processing-tools

# %% [markdown]
# ### Tokenization & Lemmatization

# %%
df['tokenized']=df['tweet_formatted_lower'].apply(lambda x:nltk.word_tokenize(x))

# %%
# initializing wordnet libraries

nltk.download('wordnet')
lemmatizer=nltk.stem.WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Revathi
# [nltk_data]     P\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df['lemmatized']=df['tokenized'].apply(lambda x:[lemmatizer.lemmatize(i) for i in x])

# %% [markdown]
# #### Stop word elimination

# %%
# initializing Stop words libraries

nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Revathi
# [nltk_data]     P\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords=nltk.corpus.stopwords
df['lemmatized']=df['lemmatized'].apply(lambda x: " ".join([i for i in x if i.lower() not in stopwords.words('english')]))

# %% [markdown]
# #### Ngram

# %%
#Bi-grams 
from sklearn.feature_extraction.text import CountVectorizer

def plot_top_ngrams_barchart(text, n=2):
    stop=set(stopwords.words('english'))

    new= text.str.split()
    new=new.values.tolist()
    corpus=[word for i in new for word in i]

    def _get_top_ngram(corpus, n=None):
        vec = CountVectorizer(ngram_range=(n, n)).fit(corpus)
        bag_of_words = vec.transform(corpus)
        sum_words = bag_of_words.sum(axis=0) 
        words_freq = [(word, sum_words[0, idx]) 
                      for word, idx in vec.vocabulary_.items()]
        words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
        return words_freq[:20]

    top_n_bigrams=_get_top_ngram(text,n)[:20]
    x,y=map(list,zip(*top_n_bigrams))
    plt.figure(figsize=(12,10))
    plt.xlabel("Bi-gram Frequency")
    plt.ylabel("Top 20 bi-grams mentioned in Tweets")
    sns.barplot(x=y,y=x)


plot_top_ngrams_barchart(df['lemmatized'],2)

# %%
#Tri-grams 

def plot_top_ngrams_barchart(text, n=3):
    stop=set(stopwords.words('english'))

    new= text.str.split()
    new=new.values.tolist()
    corpus=[word for i in new for word in i]

    def _get_top_ngram(corpus, n=None):
        vec = CountVectorizer(ngram_range=(n, n)).fit(corpus)
        bag_of_words = vec.transform(corpus)
        sum_words = bag_of_words.sum(axis=0) 
        words_freq = [(word, sum_words[0, idx]) 
                      for word, idx in vec.vocabulary_.items()]
        words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
        return words_freq[:20]

    top_n_bigrams=_get_top_ngram(text,n)[:20]
    x,y=map(list,zip(*top_n_bigrams))
    plt.figure(figsize=(10,10))
    plt.xlabel("Tri-gram Frequency")
    plt.ylabel("Top 20 tri-grams mentioned in Tweets")
    sns.barplot(x=y,y=x)


plot_top_ngrams_barchart(df['lemmatized'],3)

# %% [markdown]
# ### Checking emotion type using Polarity & subjectivity

# %%
from textblob import TextBlob

# %%
def getanalysis(score):
    if score < 0:
        return "negative"
    if score == 0:
        return "neutral"
    if score > 0:
        return "positive"

# %%
df['Polarity']=df['tweet_formatted_lower'].apply(lambda x:TextBlob(x).polarity)
df['Subjectivity']=df['tweet_formatted_lower'].apply(lambda x:TextBlob(x).subjectivity)
df['Analysis'] = df.Polarity.apply(getanalysis)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12, 3))
sns.histplot(data = df['Polarity'], legend=False, bins = 12)
# Out:
# <AxesSubplot:xlabel='Polarity', ylabel='Count'>

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12, 3))
sns.histplot(data = df['Subjectivity'], legend=False, bins = 12)
# Out:
# <AxesSubplot:xlabel='Subjectivity', ylabel='Count'>

# %%
sns.set(font_scale=1.2)
sns.set_style('whitegrid')

plt.figure(figsize=(16, 6))
sns.scatterplot(data=df, x= "Polarity", y= "Subjectivity", 
                     hue='Analysis', 
                     palette='cool', legend=False)
# Out:
# <AxesSubplot:xlabel='Polarity', ylabel='Subjectivity'>

# %%
df.Analysis.value_counts()
# Out:
# negative    5495
# positive    2090
# neutral      359
# Name: Analysis, dtype: int64

# %%
# percentage of positive subjects
ps= df[df.Analysis=="positive"]
pct= (ps.shape[0]/df.shape[0])
print(f'Percentage of positive tweets: {pct*100:.2f}%')

# percentage of negative subjects
ps= df[df.Analysis=="negative"]
pct= (ps.shape[0]/df.shape[0])
pct
print(f'Percentage of negative tweets: {pct*100:.2f}%')

# percentage of neutral subjects
ps= df[df.Analysis=="neutral"]
pct= (ps.shape[0]/df.shape[0])
pct
print(f'Percentage of neutral tweets: {pct*100:.2f}%')

# show the count
df.Analysis.value_counts().plot(kind="bar")
# Out:
# Percentage of positive tweets: 26.31%
# Percentage of negative tweets: 69.17%
# Percentage of neutral tweets: 4.52%
# <AxesSubplot:>

# %%
len(df)
# Out:
# 7944

# %%
df.to_csv('Tweets_formatted_CongestiveHeartFailure_08022022.csv')

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Revathi P\Documents\Graduate Research - Twitter Analysis\My notebooks\Combined\Tweets_formatted_CongestiveHeartFailure_08022022.csv")

# %% [markdown]
# ### Creating a column for Emoji presence

# %%
# !pip install pip --upgrade
# !pip --version
# Out:
# Requirement already satisfied: pip in c:\users\revathi p\anaconda3\lib\site-packages (22.2.2)
# pip 22.2.2 from C:\Users\Revathi P\anaconda3\lib\site-packages\pip (python 3.9)

# %%
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# !pip install spacymoji

import spacy
from spacymoji import Emoji

nlp = spacy.load("en_core_web_sm")
emoji = Emoji(nlp)
nlp.add_pipe("emoji", first=True)

nlp.pipe_names
# Out:
# Requirement already satisfied: pip in c:\users\revathi p\anaconda3\lib\site-packages (22.2.2)
# Requirement already satisfied: setuptools in c:\users\revathi p\anaconda3\lib\site-packages (63.4.1)
# Requirement already satisfied: wheel in c:\users\revathi p\anaconda3\lib\site-packages (0.37.1)
# Requirement already satisfied: spacy in c:\users\revathi p\anaconda3\lib\site-packages (3.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (3.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (4.62.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (21.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (1.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (1.22.3)
# Requirement already satisfied: setuptools in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (63.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (2.28.0)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (0.6.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (1.8.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: jinja2 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (2.4.3)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (8.1.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (0.9.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\revathi p\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\revathi p\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\revathi p\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy) (4.2.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\revathi p\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\revathi p\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\revathi p\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\revathi p\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\revathi p\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.8)
# Requirement already satisfied: colorama in c:\users\revathi p\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\revathi p\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\revathi p\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Collecting en-core-web-sm==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.0/en_core_web_sm-3.4.0-py3-none-any.whl (12.8 MB)
#      --------------------------------------- 12.8/12.8 MB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\users\revathi p\anaconda3\lib\site-packages (from en-core-web-sm==3.4.0) (3.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.9.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.28.0)
# Requirement already satisfied: jinja2 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.11.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (8.1.0)
# Requirement already satisfied: setuptools in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (63.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (21.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.22.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.4.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.4.1)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.6.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.8.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.0.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (4.62.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\revathi p\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\revathi p\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\revathi p\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (4.2.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\revathi p\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\revathi p\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\revathi p\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\revathi p\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.26.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\revathi p\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.7.8)
# Requirement already satisfied: colorama in c:\users\revathi p\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\revathi p\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\revathi p\anaconda3\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Requirement already satisfied: spacymoji in c:\users\revathi p\anaconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: emoji<1.0.0,>=0.4.5 in c:\users\revathi p\anaconda3\lib\site-packages (from spacymoji) (0.6.0)
# Requirement already satisfied: spacy<4.0.0,>=3.0.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacymoji) (3.4.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (8.1.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (21.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (4.62.3)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (0.6.1)
# Requirement already satisfied: setuptools in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (63.4.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (1.0.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (2.4.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (0.9.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (1.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (2.28.0)
# Requirement already satisfied: jinja2 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (2.11.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (0.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (1.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (3.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (3.3.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\revathi p\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacymoji) (1.22.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\revathi p\anaconda3\lib\site-packages (from packaging>=20.0->spacy<4.0.0,>=3.0.0->spacymoji) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\revathi p\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<4.0.0,>=3.0.0->spacymoji) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\revathi p\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy<4.0.0,>=3.0.0->spacymoji) (4.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\revathi p\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacymoji) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\revathi p\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacymoji) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\revathi p\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacymoji) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\revathi p\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacymoji) (2.10)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\revathi p\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<4.0.0,>=3.0.0->spacymoji) (0.7.8)
# Requirement already satisfied: colorama in c:\users\revathi p\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4.0.0,>=3.0.0->spacymoji) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\revathi p\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacymoji) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\revathi p\anaconda3\lib\site-packages (from jinja2->spacy<4.0.0,>=3.0.0->spacymoji) (1.1.1)
# ['emoji',
#  'tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner']

# %%
def extract_emojies(x):
  doc = nlp(x['tweet']) #with emojis
  
  emojis = [1 if token._.is_emoji else 0 for token in doc ]
  emoji_tag = [1 if 1 in emojis else 0][0]
  return emoji_tag

df['emoji_tag'] = df.apply(extract_emojies,axis=1)

# %%
df.to_csv(r"C:\Users\Revathi P\Documents\Graduate Research - Twitter Analysis\My notebooks\Combined\Tweets_formatted_CongestiveHeartFailure_08022022.csv")

# %% [markdown]
# ### Emoji Count

# %%
def extract_emojies(x):
  doc = nlp(x['tweet']) #with emojis
  
  emojis = [token.text for token in doc if token._.is_emoji]
  
  return emojis

emojies_df = df.apply(extract_emojies,axis=1)
#emojies_df.head(30)

# %%
emoji_counts = (emojies_df
                .apply(pd.Series) #breaks up the list into seperate columns 
                .stack() #collapses each column into one column
                .value_counts() #counts the frequency of each item
                .rename('Count')
                .sort_values()
                .reset_index()
                .rename(columns={'index':'Emoji'}))
emoji_counts
# Out:
#     Emoji  Count
# 0       😵      1
# 1      ☝️      1
# 2       🧼      1
# 3       🦠      1
# 4       🧤      1
# ..    ...    ...
# 268     😂     40
# 269     🙏     49
# 270     😭     63
# 271     💔     66
# 272    ❤️     77
#
# [273 rows x 2 columns]

# %%
#emoji_counts['Count'].sort()
emoji_counts.sort_values(by = 'Count', ascending=False)
# Out:
#     Emoji  Count
# 272    ❤️     77
# 271     💔     66
# 270     😭     63
# 269     🙏     49
# 268     😂     40
# ..    ...    ...
# 97    5️⃣      1
# 98     👴🏾      1
# 99      💰      1
# 100     ❌      1
# 136     📢      1
#
# [273 rows x 2 columns]

# %%
emoji_counts.to_csv(r"C:\Users\Revathi P\Documents\Graduate Research - Twitter Analysis\My notebooks\Combined\CHF_emoji.csv")
